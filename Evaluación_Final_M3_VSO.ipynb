# %%
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
#from scipy.stats import shapiro, kstest, poisson, chisquare, ttest_ind, levene, bartlett, sem, ppf
import scipy.stats as stats
from scipy.stats import shapiro, levene
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import chi2_contingency

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# Abro los csv
df_flights = pd.read_csv("Customer Flight Activity.csv")
df_loyalty = pd.read_csv("Customer Loyalty History.csv")

# %% [markdown]
# ## FASE 1: EXPLORACIÓN Y LIMPIEZA ##

# %%
# EXPLORACIÓN INICIAL

# %%
# Exploro las 5 primeras filas de "df_flights"
df_flights.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
# Exploro las 5 últimas filas de "df_flights"
df_flights.tail()
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405619                            0
# 405620                            0
# 405621                            0
# 405622                            0
# 405623                            0

# %%
# Exploro las 10 filas aleatorias de "df_flights"
df_flights.sample(10)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 205417          240500  2018      1               0                        0
# 43966           191057  2018      2               0                        0
# 54203           287224  2017      4               0                        0
# 190709          356460  2017     12               3                        2
# 241658          608493  2018      3              12                        0
# 223749          349767  2018      2               1                        1
# 378875          476288  2018     11               4                        3
# 350149          744181  2018      9               0                        0
# 166193          847559  2017     10               9                        0
# 103816          229436  2017      7               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 205417              0         0                0.00                0
# 43966               0         0                0.00                0
# 54203               0         0                0.00                0
# 190709              5      3220              322.00                0
# 241658             12      2412              260.28                0
# 223749              2       352               43.75                0
# 378875              7      1358              135.00                0
# 350149              0         0                0.00                0
# 166193              9      1899              189.00                0
# 103816              0         0                0.00                0
#
#         Dollar Cost Points Redeemed
# 205417                            0
# 43966                             0
# 54203                             0
# 190709                            0
# 241658                            0
# 223749                            0
# 378875                            0
# 350149                            0
# 166193                            0
# 103816                            0

# %%
# Compruebo el total de filas y columnas de "df_flights"
df_flights.shape
# Out:
# (405624, 10)

# %%
# Exploro las 5 primeras filas de "df_loyalty"
df_loyalty.head()
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN
# 2             2014                 7             2018.0                 1.0
# 3             2013                 2                NaN                 NaN
# 4             2014                10                NaN                 NaN

# %%
# Exploro las 5 últimas filas de "df_loyalty"
df_loyalty.tail()
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 16732          823768  Canada  British Columbia   Vancouver     V6E 3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J 3C5
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education   Salary Marital Status Loyalty Card       CLV  \
# 16732  Female   College      NaN        Married         Star  61850.19
# 16733  Female  Bachelor  89210.0        Married         Star  67907.27
# 16734    Male   College      NaN         Single         Star  74228.52
# 16735    Male  Bachelor -57297.0        Married         Star  10018.66
# 16736  Female  Bachelor  75049.0        Married         Star  83325.38
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 16732        Standard             2012                12                NaN
# 16733        Standard             2014                 9                NaN
# 16734        Standard             2014                 3                NaN
# 16735  2018 Promotion             2018                 4                NaN
# 16736        Standard             2015                12             2016.0
#
#        Cancellation Month
# 16732                 NaN
# 16733                 NaN
# 16734                 NaN
# 16735                 NaN
# 16736                 8.0

# %%
# Exploro las 10 filas aleatorias de "df_loyalty"
df_loyalty.sample(10)
# Out:
#        Loyalty Number Country          Province          City Postal Code  \
# 11051          114214  Canada            Quebec      Montreal     H2T 9K8
# 12601          131463  Canada  British Columbia     Vancouver     V1E 4R6
# 11973          562084  Canada           Ontario       Toronto     M8Y 4K8
# 9829           990512  Canada           Ontario       Toronto     P1W 1K4
# 10192          392682  Canada  British Columbia      Victoria     V10 6T5
# 1999           208234  Canada            Quebec      Montreal     H4G 3T4
# 7811           345244  Canada           Ontario   Thunder Bay     K8T 5M5
# 4287           106689  Canada           Ontario       Toronto     P1W 1K4
# 12029          454690  Canada  British Columbia     Vancouver     V5R 1W3
# 1880           523188  Canada  British Columbia  Dawson Creek     U5I 4F1
#
#        Gender Education    Salary Marital Status Loyalty Card      CLV  \
# 11051  Female   College       NaN        Married         Star  2554.55
# 12601    Male  Bachelor   55406.0        Married         Star  4128.09
# 11973    Male  Bachelor   96153.0        Married         Star  2882.35
# 9829     Male   College       NaN         Single         Star  1904.00
# 10192  Female   College       NaN        Married         Star  2356.07
# 1999   Female   College       NaN       Divorced       Aurora  7281.25
# 7811     Male  Bachelor  103320.0       Divorced         Nova  7756.44
# 4287   Female  Bachelor   61554.0        Married         Nova  2795.41
# 12029    Male  Bachelor   70951.0        Married         Star  2939.33
# 1880     Male   College       NaN       Divorced       Aurora  8714.92
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 11051        Standard             2017                 5             2018.0
# 12601        Standard             2013                 4                NaN
# 11973        Standard             2014                11                NaN
# 9829         Standard             2015                10                NaN
# 10192        Standard             2017                10                NaN
# 1999         Standard             2014                 7                NaN
# 7811         Standard             2014                 8                NaN
# 4287         Standard             2017                 6                NaN
# 12029        Standard             2017                 3                NaN
# 1880   2018 Promotion             2018                 3                NaN
#
#        Cancellation Month
# 11051                 4.0
# 12601                 NaN
# 11973                 NaN
# 9829                  NaN
# 10192                 NaN
# 1999                  NaN
# 7811                  NaN
# 4287                  NaN
# 12029                 NaN
# 1880                  NaN

# %%
# Compruebo el total de filas y columnas de "df_loyalty"
df_loyalty.shape
# Out:
# (16737, 16)

# %%
# Compruebo valores nulos para "df_flights"
# Observo que en este df NO tengo
df_flights.isnull().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
# Compruebo valores nulos para "df_loyalty". 
df_loyalty.isnull().sum()
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %%
# En "df_loyalty" encuentro que tengo nulos en las columnas: "Salary", "Cancellation Year", "Cancellation Month". Miro de que tipo son estas columnas.
df_loyalty.dtypes
# Out:
# Loyalty Number          int64
# Country                object
# Province               object
# City                   object
# Postal Code            object
# Gender                 object
# Education              object
# Salary                float64
# Marital Status         object
# Loyalty Card           object
# CLV                   float64
# Enrollment Type        object
# Enrollment Year         int64
# Enrollment Month        int64
# Cancellation Year     float64
# Cancellation Month    float64
# dtype: object

# %%
# Lo observo en procentaje. En el siguiente punto de la fase exploración, analizo como voy a proceder con los datos nulos.
df_loyalty.isnull().sum() / df_loyalty.shape[0] * 100
# Out:
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# CLV                    0.000000
# Enrollment Type        0.000000
# Enrollment Year        0.000000
# Enrollment Month       0.000000
# Cancellation Year     87.650117
# Cancellation Month    87.650117
# dtype: float64

# %%
# Observo si hay duplicado en "df_flights"
df_flights.duplicated().sum()
# Out:
# 1864

# %%
# Observo si hay duplicado en "df_loyalty"
df_loyalty.duplicated().sum()
# Out:
# 0

# %%
# Solo tengo duplicados en "df_flights", analizo cuáles son. "keep=False" Duplicados en todas las columnas
# Observo que se repiten los valores en la columna "Loyalty Number"

df_flights[df_flights.duplicated(keep=False)]
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 41              101902  2017      1               0                        0
# 42              101902  2017      1               0                        0
# 226             112142  2017      1               0                        0
# 227             112142  2017      1               0                        0
# 477             126100  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405111          971370  2018     12               0                        0
# 405409          988392  2018     12               0                        0
# 405410          988392  2018     12               0                        0
# 405436          989528  2018     12               0                        0
# 405437          989528  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 41                  0         0                 0.0                0
# 42                  0         0                 0.0                0
# 226                 0         0                 0.0                0
# 227                 0         0                 0.0                0
# 477                 0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 405111              0         0                 0.0                0
# 405409              0         0                 0.0                0
# 405410              0         0                 0.0                0
# 405436              0         0                 0.0                0
# 405437              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 41                                0
# 42                                0
# 226                               0
# 227                               0
# 477                               0
# ...                             ...
# 405111                            0
# 405409                            0
# 405410                            0
# 405436                            0
# 405437                            0
#
# [3712 rows x 10 columns]

# %%
# Me di cuenta que colocando el indexcol=0 no me cogia "Loyalty Number" como columna. Lo cambié al leer los csv. 
df_flights.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
df_flights.duplicated(subset = "Loyalty Number").sum()
# Out:
# 388887
