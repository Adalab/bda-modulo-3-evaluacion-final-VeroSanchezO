# %%
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
#from scipy.stats import shapiro, kstest, poisson, chisquare, ttest_ind, levene, bartlett, sem, ppf
import scipy.stats as stats
from scipy.stats import shapiro, levene
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import chi2_contingency

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# Abro los csv
df_flights = pd.read_csv("Customer Flight Activity.csv", index_col = 0)
df_loyalty = pd.read_csv("Customer Loyalty History.csv", index_col = 0)

# %% [markdown]
# ## FASE 1: EXPLORACIÓN Y LIMPIEZA ##

# %%
# EXPLORACIÓN INICIAL

# %%
# Exploro las 5 primeras filas de "df_flights"
df_flights.head()
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017      1               3                        0
# 100102          2017      1              10                        4
# 100140          2017      1               6                        0
# 100214          2017      1               0                        0
# 100272          2017      1               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 100018                                    0
# 100102                                    0
# 100140                                    0
# 100214                                    0
# 100272                                    0

# %%
# Exploro las 5 últimas filas de "df_flights"
df_flights.tail()
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 999902          2018     12               0                        0
# 999911          2018     12               0                        0
# 999940          2018     12               3                        0
# 999982          2018     12               0                        0
# 999986          2018     12               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 999902                      0         0                 0.0                0
# 999911                      0         0                 0.0                0
# 999940                      3      1233               123.0                0
# 999982                      0         0                 0.0                0
# 999986                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 999902                                    0
# 999911                                    0
# 999940                                    0
# 999982                                    0
# 999986                                    0

# %%
# Exploro las 10 filas aleatorias de "df_flights"
df_flights.sample(10)
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 917191          2018      6               0                        0
# 365887          2018      1               0                        0
# 727348          2018     11               1                        0
# 193827          2018      4               0                        0
# 309408          2017     12               6                        0
# 800196          2018      1               0                        0
# 373665          2018     12               0                        0
# 200168          2018      6              14                        0
# 472356          2018      3               0                        0
# 756791          2018      3              14                        2
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 917191                      0         0                0.00                0
# 365887                      0         0                0.00                0
# 727348                      1      2935              293.00                0
# 193827                      0         0                0.00                0
# 309408                      6       876               87.00                0
# 800196                      0         0                0.00                0
# 373665                      0         0                0.00                0
# 200168                     14      2044              204.00                0
# 472356                      0         0                0.00                0
# 756791                     16      4464              481.68                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 917191                                    0
# 365887                                    0
# 727348                                    0
# 193827                                    0
# 309408                                    0
# 800196                                    0
# 373665                                    0
# 200168                                    0
# 472356                                    0
# 756791                                    0

# %%
# compruebo el total de filas y columnas de "df_flights"
df_flights.shape
# Out:
# (405624, 9)

# %%
# Exploro las 5 primeras filas de "df_loyalty"
df_loyalty.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
#                Enrollment Type  Enrollment Year  Enrollment Month  \
# Loyalty Number
# 480934                Standard             2016                 2
# 549612                Standard             2016                 3
# 429460                Standard             2014                 7
# 608370                Standard             2013                 2
# 530508                Standard             2014                10
#
#                 Cancellation Year  Cancellation Month
# Loyalty Number
# 480934                        NaN                 NaN
# 549612                        NaN                 NaN
# 429460                     2018.0                 1.0
# 608370                        NaN                 NaN
# 530508                        NaN                 NaN

# %%
# Exploro las 5 últimas filas de "df_loyalty"
df_loyalty.tail()
# Out:
#                Country          Province        City Postal Code  Gender  \
# Loyalty Number
# 823768          Canada  British Columbia   Vancouver     V6E 3Z3  Female
# 680886          Canada      Saskatchewan      Regina     S1J 3C5  Female
# 776187          Canada  British Columbia   Vancouver     V5R 1W3    Male
# 906428          Canada             Yukon  Whitehorse     Y2K 6R0    Male
# 652627          Canada          Manitoba    Winnipeg     R2C 0M5  Female
#
#                Education   Salary Marital Status Loyalty Card       CLV  \
# Loyalty Number
# 823768           College      NaN        Married         Star  61850.19
# 680886          Bachelor  89210.0        Married         Star  67907.27
# 776187           College      NaN         Single         Star  74228.52
# 906428          Bachelor -57297.0        Married         Star  10018.66
# 652627          Bachelor  75049.0        Married         Star  83325.38
#
#                Enrollment Type  Enrollment Year  Enrollment Month  \
# Loyalty Number
# 823768                Standard             2012                12
# 680886                Standard             2014                 9
# 776187                Standard             2014                 3
# 906428          2018 Promotion             2018                 4
# 652627                Standard             2015                12
#
#                 Cancellation Year  Cancellation Month
# Loyalty Number
# 823768                        NaN                 NaN
# 680886                        NaN                 NaN
# 776187                        NaN                 NaN
# 906428                        NaN                 NaN
# 652627                     2016.0                 8.0

# %%
# Exploro las 10 filas aleatorias de "df_loyalty"
df_loyalty.sample(10)
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 247514          Canada           Ontario    Toronto     P1L 8X8  Female
# 942819          Canada            Quebec   Montreal     H2Y 4R4  Female
# 971097          Canada           Ontario    Sudbury     M5V 1G5    Male
# 979135          Canada           Ontario    Toronto     P2T 6G3    Male
# 778027          Canada  British Columbia  Vancouver     V1E 4R6  Female
# 414433          Canada          Manitoba   Winnipeg     R3R 3T4  Female
# 364264          Canada           Ontario    Toronto     M2M 7K8  Female
# 612719          Canada  British Columbia  Vancouver     V5R 1W3  Female
# 267352          Canada           Ontario    Toronto     M2M 7K8    Male
# 200012          Canada           Ontario    Toronto     M2Z 4K1  Female
#
#                Education    Salary Marital Status Loyalty Card       CLV  \
# Loyalty Number
# 247514          Bachelor   82509.0         Single         Nova   3319.62
# 942819            Doctor   80786.0        Married       Aurora   7679.68
# 971097           College       NaN         Single       Aurora   6872.04
# 979135           College       NaN         Single         Star   2279.75
# 778027          Bachelor   67115.0        Married       Aurora  15362.35
# 414433          Bachelor   89230.0       Divorced       Aurora  21892.35
# 364264          Bachelor   73945.0         Single         Nova  12157.33
# 612719            Doctor  250798.0         Single         Star   2482.41
# 267352           College       NaN         Single         Star  19069.50
# 200012           College       NaN         Single         Star   2161.69
#
#                Enrollment Type  Enrollment Year  Enrollment Month  \
# Loyalty Number
# 247514                Standard             2013                 7
# 942819                Standard             2014                 4
# 971097                Standard             2014                10
# 979135          2018 Promotion             2018                 3
# 778027                Standard             2018                 5
# 414433                Standard             2013                 2
# 364264                Standard             2016                 3
# 612719                Standard             2012                 7
# 267352                Standard             2013                 6
# 200012                Standard             2016                 6
#
#                 Cancellation Year  Cancellation Month
# Loyalty Number
# 247514                        NaN                 NaN
# 942819                        NaN                 NaN
# 971097                        NaN                 NaN
# 979135                        NaN                 NaN
# 778027                        NaN                 NaN
# 414433                        NaN                 NaN
# 364264                        NaN                 NaN
# 612719                        NaN                 NaN
# 267352                        NaN                 NaN
# 200012                        NaN                 NaN

# %%
# compruebo el total de filas y columnas de "df_loyalty"
df_loyalty.shape
# Out:
# (16737, 15)
